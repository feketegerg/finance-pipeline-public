# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('./sources/tranzakciok.xlsx')
df.head()
# Out:
# c:\Users\feket\Desktop\Center\home-lab\finance-pipeline\venv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      Tranzakció dátuma Könyvelés dátuma               Típus Bejövő/Kimenő  \
# 0  2026-01-01 07:36:00       2026-01-01       KAMATJÓVÁÍRÁS        Bejövő
# 1  2026-01-01 07:36:00       2026-01-01      HAVI CSOMAGDÍJ        Kimenő
# 2  2026-01-02 13:07:57       2026-01-05  VÁSÁRLÁS KÁRTYÁVAL        Kimenő
# 3  2026-01-02 15:33:59       2026-01-05  VÁSÁRLÁS KÁRTYÁVAL        Kimenő
# 4  2026-01-03 17:51:44       2026-01-05  VÁSÁRLÁS KÁRTYÁVAL        Kimenő
#
#              Partner neve  Partner számlaszáma/azonosítója Költési kategória  \
# 0           KAMATJÓVÁÍRÁS                              NaN    Számlák, rezsi
# 1          HAVI CSOMAGDÍJ                              NaN    Számlák, rezsi
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Tranzakció dátuma                79 non-null     str
#  1   Könyvelés dátuma                 75 non-null     str
#  2   Típus                            75 non-null     str
#  3   Bejövő/Kimenő                    79 non-null     str
#  4   Partner neve                     79 non-null     str
#  5   Partner számlaszáma/azonosítója  3 non-null      float64
#  6   Költési kategória                79 non-null     str
#  7   Közlemény                        72 non-null     str
#  8   Számla név                       79 non-null     str
#  9   Számla szám                      79 non-null     int64
#  10  Összeg                           79 non-null     int64
#  11  Pénznem                          79 non-null     str
# dtypes: float64(1), int64(2), str(9)
# ...

# %%
df[df["Partner számlaszáma/azonosítója"].notna()]
# Out:
#       Tranzakció dátuma Könyvelés dátuma                            Típus  \
# 45  2026-01-19 22:11:25       2026-01-20    AZONNALI FIZETÉS BANKON BELÜL
# 46  2026-01-20 01:38:00       2026-01-20        ESETI MEGBÍZÁSOK KÖLTSÉGE
# 71  2026-01-30 07:48:00       2026-01-30  NAPKÖZBENI ÁTUTALÁS (CSOPORTOS)
#
#    Bejövő/Kimenő                      Partner neve  \
# 45        Kimenő                 Tóth Máté Gergely
# 46        Kimenő         ESETI MEGBÍZÁSOK KÖLTSÉGE
# 71        Bejövő  UNICREDIT BANK ZRT. IZV SUSPENSE
#
#     Partner számlaszáma/azonosítója Költési kategória           Közlemény  \
# 45                     1.173801e+15            Utalás  Fekete Gergő teája
# 46                     1.173801e+15             Egyéb                 NaN
# 71                     1.091800e+23  Nem kategorizált     Munkabér utalás
#
#       Számla név       Számla szám  Összeg Pénznem
# 45  Bázis számla  1177340101379288  -25230     HUF
# 46  Bázis számla  1177340101379288    -333     HUF
# ...
